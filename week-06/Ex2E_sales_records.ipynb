# %% [markdown]
# # Sales Records Analysis
# ### Author: Mohamed Mouatakid
# ### Exercise 2.E Using functions for analyzing data
# This notebook analyzes a small sales dataset using Python functions. Each function takes the full dataset as its first argument.

# %%
sales_data = [
    ('Laptop', 'East', 1200.00),
    ('Phone', 'West', 850.00),
    ('Tablet', 'East', 400.00),
    ('Monitor', 'South', 650.00),
    ('Keyboard', 'West', 75.00),
    ('Laptop', 'South', 1150.00),
    ('Phone', 'East', 900.00),
    ('Tablet', 'West', 425.00),
    ('Monitor', 'East', 680.00),
    ('Keyboard', 'South', 80.00),
    ('Laptop', 'West', 1300.00),
    ('Phone', 'West', 820.00),
]
# Each tuple has product, region, and sale amount.

# %% [markdown]
# ## Lab 1. Total sales by region

# %%
def region_total(data, region):
    # I use sum with a generator expression to add only the matching region.
    return sum(amt for _, r, amt in data if r == region)

# %%
print(region_total(sales_data, 'East'))
print(region_total(sales_data, 'West'))
print(region_total(sales_data, 'South'))

# %% [markdown]
# ## Lab 2. Count of sales by region

# %%
def region_count(data, region):
    # I count matching records by adding 1 every time the region matches.
    return sum(1 for _, r, _ in data if r == region)

# %%
print(region_count(sales_data, 'East'))
print(region_count(sales_data, 'West'))
print(region_count(sales_data, 'South'))

# %% [markdown]
# ## Lab 3. Average sale amount by region

# %%
def region_average(data, region):
    # I reuse my previous functions instead of rewriting the same logic.
    count = region_count(data, region)
    if count == 0:
        return 0
    return region_total(data, region) / count

# %%
print(region_average(sales_data, 'East'))
print(region_average(sales_data, 'West'))
print(region_average(sales_data, 'South'))
print(region_average(sales_data, 'North'))

# %% [markdown]
# ## Lab 4. Filter by sale amount

# %%
def sales_above(data, threshold):
    # I return only records where the sale amount is above my threshold.
    return [record for record in data if record[2] > threshold]

# %%
for record in sales_above(sales_data, 500):
    print(record)

# %%
def sales_below(data, threshold):
    # Bonus: same pattern, but now I return sales below the threshold.
    return [record for record in data if record[2] < threshold]

for record in sales_below(sales_data, 500):
    print(record)

# %% [markdown]
# ## Lab 5. Top and bottom sale

# %%
def top_sale(data):
    return max(data, key=lambda s: s[2])

def bottom_sale(data):
    return min(data, key=lambda s: s[2])

# %%
print(top_sale(sales_data))
print(bottom_sale(sales_data))

# %% [markdown]
# The top sale was a Laptop in the West region for $1,300.00. The bottom sale was a Keyboard in the West region for $75.00.

# %% [markdown]
# ## Lab 6. Apply a discount

# %%
def apply_discount(data, discount_pct):
    # map applies the discount to every record and returns a new list.
    return list(map(lambda s: (s[0], s[1], s[2] * (1 - discount_pct)), data))

# %%
discounted = apply_discount(sales_data, 0.15)
print('Before discount:')
for record in sales_data[:3]:
    print(record)
print('After discount:')
for record in discounted[:3]:
    print(record)

# %% [markdown]
# ## Lab 7. Unique regions

# %%
def unique_regions(data):
    # set removes duplicates and sorted puts the regions in order.
    return sorted(set(r for _, r, _ in data))

print(unique_regions(sales_data))

# %% [markdown]
# This function is useful because it lets me automatically find every region in the dataset. I can use the same pattern for products, categories, cities, or any field where I need a unique list before doing analysis.

# %% [markdown]
# ## Lab 8. Region summary

# %%
def region_summary(data, region):
    region_records = [record for record in data if record[1] == region]
    print(f"=== {region} Region ===")
    print(f"Records: {region_count(data, region)}")
    print(f"Total Sales: ${region_total(data, region):,.2f}")
    print(f"Average Sale: ${region_average(data, region):,.2f}")
    if region_records:
        top = top_sale(region_records)
        print(f"Top Sale: {top[0]} — ${top[2]:,.2f}")
    else:
        print('Top Sale: None')

# %%
region_summary(sales_data, "East")

# %% [markdown]
# ## Lab 9. Full summary

# %%
for region in unique_regions(sales_data):
    region_summary(sales_data, region)
    print()
# I used unique_regions so the region names are not hardcoded.

# %% [markdown]
# In this lab I learned how to write reusable functions for analysis. Instead of repeating calculations, I can make one function and call it many times for different regions.
