# %% [markdown]
# # Exercise 1.A NumPy: Manipulating Arrays

# %%
import numpy as np

# %% [markdown]
# ## Looping Through Arrays

# %%
arrA = np.array([(11, 12, 13), (14, 15, 16)])

# %%
print(arrA)
# Out:
# [[11 12 13]
#  [14 15 16]]

# %%
for x in arrA:
    print(x * 2)
# Out:
# [22 24 26]
# [28 30 32]

# %%
for x in arrA:
    for y in x:
        print(y * 2)
# Out:
# 22
# 24
# 26
# 28
# 30
# 32

# %% [markdown]
# The outer loop goes row by row and multiplies the whole row by 2, giving back an array each time.
# The inner loop goes element by element, so we get one number at a time after multiplying by 2.

# %%
for x in arrA:
    for y in x:
        loop_result = x * 2
        print(loop_result)
#loop_result miltiplies the whole row x by 2, not just y so even though we loop through each element with y
#prints entire row 3 times.
# Out:
# [22 24 26]
# [22 24 26]
# [22 24 26]
# [28 30 32]
# [28 30 32]
# [28 30 32]

# %% [markdown]
# ## Joining and Stacking Arrays

# %%
joined_array_1 = np.concatenate((arrA, arrA), axis=0)
print(joined_array_1)
# Out:
# [[11 12 13]
#  [14 15 16]
#  [11 12 13]
#  [14 15 16]]

# %%
joined_array_2 = np.concatenate((arrA, arrA), axis=1)
print(joined_array_2)
# Out:
# [[11 12 13 11 12 13]
#  [14 15 16 14 15 16]]

# %%
stacked_array_1 =np.stack((joined_array_1, joined_array_1))
print(stacked_array_1)
# Out:
# [[[11 12 13]
#   [14 15 16]
#   [11 12 13]
#   [14 15 16]]
#
#  [[11 12 13]
#   [14 15 16]
#   [11 12 13]
#   [14 15 16]]]

# %%
stacked_array_2 = np.stack((joined_array_1, joined_array_2))
print(stacked_array_2)

#ValueError: all input arrays must have the same shape. joined_array_1 has 4 rows but arrA has 2 rows
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 stacked_array_2 = np.stack((joined_array_1, joined_array_2))
#       2 print(stacked_array_2)
#       3
#       4 #ValueError: all input arrays must have the same shape. joined_array_1 has 4 rows but arrA has 2 rows
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/numpy/_core/shape_base.py:458, in stack(arrays, axis, out, dtype, casting)
#     456 shapes = {arr.shape for arr in arrays}
#     457 if len(shapes) != 1:
# --> 458     raise ValueError('all input arrays must have the same shape')
#     460 result_ndim = arrays[0].ndim + 1
#     461 axis = normalize_axis_index(axis, result_ndim)
#
# ValueError: all input arrays must have the same shape

# %%
h = np.hstack((arrA, arrA))
print(h)
#hstack horizontally - same as axis=1, adds columns

v = np.vstack((arrA, arrA))
print(v)
#vstack stacks vertically - same as axis=0, adds rows

d = np.dstack((arrA, arrA))
print(d)
#dstack stacks depth-wise - adds a third dimension
# Out:
# [[11 12 13 11 12 13]
#  [14 15 16 14 15 16]]
# [[11 12 13]
#  [14 15 16]
#  [11 12 13]
#  [14 15 16]]
# [[[11 11]
#   [12 12]
#   [13 13]]
#
#  [[14 14]
#   [15 15]
#   [16 16]]]

# %% [markdown]
# ## Splitting Arrays

# %%
splitsky = np.array_split(joined_array_1, 2)
print(splitsky)
#Result: 2 arrays, each with 2 rows and 3 columns(2D)
# Out:
# [array([[11, 12, 13],
#        [14, 15, 16]]), array([[11, 12, 13],
#        [14, 15, 16]])]

# %%
spliterino = np.array_split(joined_array_1, 3)
print(spliterino)
#Result: 3 arrays - first two have 2 rows, last has 0 rows (2D each)
# Out:
# [array([[11, 12, 13],
#        [14, 15, 16]]), array([[11, 12, 13]]), array([[14, 15, 16]])]

# %% [markdown]
# ## Searching and Replacing Array Values

# %%
result_1 = np.where(arrA % 2 == 0, arrA, 'odd')
print(result_1)
# % 2 == 0 checks if number is even
# if even: keep the vlaue from arrA
#if odd: replace with 'odd'
# Out:
# [['odd' '12' 'odd']
#  ['14' 'odd' '16']]

# %% [markdown]
# ## Sorting and Filtering Arrays

# %%
arrB = np.array([(7, 6), (13, 5), (7, 3)])
arrB_sorted = np.sort(arrB)
print(arrB_sorted)
#sorts each row from smallest to largest
# Out:
# [[ 6  7]
#  [ 5 13]
#  [ 3  7]]

# %%
print(arrB)
z = arrB < 7
arrC = arrB[z]
print(arrC)
#z is a boolean array - True where value < 7, False otherwise
#arrC contains only values where z is True
# Out:
# [[ 7  6]
#  [13  5]
#  [ 7  3]]
# [6 5 3]

# %%
y = arrB >= 7
arrD = arrB[y]
print(arrD)
# y is True where value >= 7
# arrD contains only those values
# Out:
# [ 7 13  7]
